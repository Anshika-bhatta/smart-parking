# %%
import simpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulation parameters
SIM_DURATION = 30 * 12 * 60  # 30 days, 12 hours per day (8 AM to 8 PM)
CAPACITY = 250
WILLINGNESS_TO_VISIT = 0.80  # 80% willingness to visit
TARGET_LOST_PERCENTAGE = 10  # Target 10% lost customers
TOLERANCE = 0.5  # Allowable deviation from the target percentage

# Arrival rates based on the day of the week and time slots
ARRIVAL_RATES = {
    'Sunday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Monday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Tuesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Wednesday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Thursday': [(8, 12, 15), (12, 17, 50), (17, 20, 50)],
    'Friday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)],
    'Saturday': [(8, 12, 20), (12, 17, 70), (17, 20, 80)]
}

# Initialize data for tracking arrivals, inter-arrival times, parking durations, revenue, and parking space utilization
def initialize_data():
    global arrival_pattern, inter_arrival_times, parking_durations, total_revenue, lost_customers, parked_customers, utilization_data
    arrival_pattern = np.zeros((30, 12))  # 30 days, 12 hours per day (8 AM to 8 PM)
    inter_arrival_times = [[] for _ in range(30 * 12)]  # List of lists for storing inter-arrival times for each time slot
    parking_durations = []  # List to store parking durations
    total_revenue = 0  # Total revenue accumulator
    lost_customers = 0  # Lost customers accumulator
    parked_customers = 0  # Parked customers accumulator
    utilization_data = []  # List to store occupancy data for utilization calculation

def get_arrival_rate(day, hour):
    """Return the arrival rate based on the day and hour."""
    for start, end, rate in ARRIVAL_RATES[day]:
        if start <= hour < end:
            return rate
    return 0

def calculate_charge(parking_duration):
    """Calculate the charge based on parking duration with ceiling logic."""
    if parking_duration < 30:
        return 15
    else:
        hours = np.ceil(parking_duration / 60)  # Round up to the nearest hour
        return 25 * hours  # Charge ₹25 per hour

def vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time):
    """Simulates vehicle parking behavior, tracks arrivals, inter-arrival times, and calculates revenue."""
    global total_revenue, lost_customers, parked_customers
    
    # Check if the vehicle decides to park based on willingness to visit
    if np.random.random() > WILLINGNESS_TO_VISIT:
        lost_customers += 1
        return  # Vehicle leaves without parking

    # Generate parking duration (in minutes)
    parking_duration = np.random.exponential(60)  # Exponential distribution with mean 60 minutes
    
    # Store parking duration
    parking_durations.append(parking_duration)
    
    # Calculate the charge based on parking duration
    charge = calculate_charge(parking_duration)
    
    # Update total revenue
    total_revenue += charge
    parked_customers += 1  # Increment parked customers counter
    
    with parking_lot.request() as request:
        yield request
        # Update occupancy data
        current_time = env.now
        num_vehicles = len(parking_lot.users)
        utilization_data.append((current_time, num_vehicles))
        yield env.timeout(parking_duration)
        # Track arrivals for the specific day and hour
        arrival_pattern[day_index, hour_index] += 1  # Use correct indexing for Numpy arrays
        # Store the inter-arrival time
        inter_arrival_times[day_index * 12 + hour_index].append(inter_arrival_time)

def arrival_process(env, parking_lot, day, day_index):
    """Simulates the arrival process based on the day and time."""
    global parked_customers, lost_customers
    while env.now < (day_index + 1) * 12 * 60:  # Simulate only 12 hours per day
        current_hour = (env.now // 60) % 12 + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        rate = get_arrival_rate(day, current_hour)
        
        # Determine the hour index (0 to 11 for 8 AM to 8 PM)
        hour_index = int(current_hour - 8)  # Adjust index to match 0-11 range
        
        if 0 <= hour_index < 12:  # Ensure hour_index is within valid bounds
            if rate > 0:
                inter_arrival_time = np.random.exponential(60 / rate)  # Convert hourly rate to inter-arrival time
                yield env.timeout(inter_arrival_time)
                env.process(vehicle(env, parking_lot, day_index, hour_index, inter_arrival_time))
            else:
                yield env.timeout(1)  # Wait for 1 minute if no arrival

def run_simulation():
    """Runs the simulation for 30 days."""
    global total_revenue, lost_customers, parked_customers
    env = simpy.Environment()
    parking_lot = simpy.Resource(env, capacity=CAPACITY)

    for day_index in range(30):
        day_name = list(ARRIVAL_RATES.keys())[day_index % 7]  # Cycle through days of the week
        env.process(arrival_process(env, parking_lot, day_name, day_index))

        # Simulate 12 hours of the current day
        env.run(until=(day_index + 1) * 12 * 60)

def adjust_arrival_rates(percentage_lost_customers):
    """Adjust arrival rates based on the percentage of lost customers."""
    adjustment_factor = 1.05 if percentage_lost_customers < TARGET_LOST_PERCENTAGE else 0.95

    # Update arrival rates based on the adjustment factor
    for day in ARRIVAL_RATES:
        updated_slots = []
        for start, end, rate in ARRIVAL_RATES[day]:
            updated_slots.append((start, end, rate * adjustment_factor))
        ARRIVAL_RATES[day] = updated_slots

# Dynamic adjustment loop
acceptable_range = (TARGET_LOST_PERCENTAGE - TOLERANCE, TARGET_LOST_PERCENTAGE + TOLERANCE)
while True:
    initialize_data()  # Reset all data accumulators
    run_simulation()  # Run the parking lot simulation

    # Calculate percentage of lost customers
    total_attempted_arrivals = parked_customers + lost_customers
    percentage_lost_customers = (lost_customers / total_attempted_arrivals) * 100 if total_attempted_arrivals > 0 else 0

    # Calculate average parking duration
    avg_parking_duration = np.mean(parking_durations) if parking_durations else 0

    # Calculate average inter-arrival time
    all_inter_arrival_times = [time for slot in inter_arrival_times for time in slot]  # Flatten list of lists
    avg_inter_arrival_time = np.mean(all_inter_arrival_times) if all_inter_arrival_times else 0

    # Calculate total parking space utilization
    time_slot_utilization = {'8-11:59': [], '12-16:59': [], '17-20:00': []}
    total_time_per_slot = {'8-11:59': 4 * 60 * 30, '12-16:59': 5 * 60 * 30, '17-20:00': 3 * 60 * 30}  # Total time per slot

    # Utility function to get time slot based on the hour
    def get_time_slot(hour):
        if 8 <= hour < 12:
            return '8-11:59'
        elif 12 <= hour < 17:
            return '12-16:59'
        elif 17 <= hour < 20:
            return '17-20:00'
        return None

    # Compute the total occupied time based on occupancy data and categorize by time slots
    previous_time = 0
    for current_time, num_vehicles in utilization_data:
        hour = int((current_time // 60) % 12) + 8  # Convert minutes to simulation hour (8 AM - 8 PM)
        time_slot = get_time_slot(hour)
        if time_slot:
            time_spent = current_time - previous_time
            time_slot_utilization[time_slot].append(time_spent * (num_vehicles / CAPACITY))
        previous_time = current_time

    # Calculate average utilization for each time slot
    average_utilization_by_slot = {
        slot: (np.sum(time_slot_utilization[slot]) / total_time_per_slot[slot]) * 100
        for slot in time_slot_utilization
    }

    # Print relevant factors
    print(f"\nSimulation Results after Adjusting Arrival Rates:")
    print(f"Current Lost Customer Percentage: {percentage_lost_customers:.2f}%")
    print(f"Total Revenue: ₹{total_revenue:.2f}")
    print(f"Average Parking Duration: {avg_parking_duration:.2f} minutes")
    print(f"Average Inter-Arrival Time: {avg_inter_arrival_time:.2f} minutes")
    print(f"Total Parked Customers: {parked_customers}")
    print(f"Total Lost Customers: {lost_customers}")

    # Print average parking space utilization by time slot
    print("\nAverage Parking Space Utilization by Time Slot:")
    for slot, utilization in average_utilization_by_slot.items():
        print(f"{slot}: {utilization:.2f}%")
    
    # Check if the lost customer percentage is within the acceptable range
    if acceptable_range[0] <= percentage_lost_customers <= acceptable_range[1]:
        print(f"Lost customer percentage is within the acceptable range: {percentage_lost_customers:.2f}%")
        break
    else:
        print(f"Adjusting arrival rates...")
        adjust_arrival_rates(percentage_lost_customers)
# Out:
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.89%
# Total Revenue: ₹440270.00
# Average Parking Duration: 60.14 minutes
# Average Inter-Arrival Time: 1.39 minutes
# Total Parked Customers: 12336
# Total Lost Customers: 3063
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 8.15%
# 12-16:59: 15.04%
# 17-20:00: 18.64%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.44%
# Total Revenue: ₹427190.00
# Average Parking Duration: 59.93 minutes
# Average Inter-Arrival Time: 1.45 minutes
# Total Parked Customers: 11991
# Total Lost Customers: 2894
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 8.32%
# 12-16:59: 14.43%
# 17-20:00: 17.83%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.97%
# Total Revenue: ₹393980.00
# Average Parking Duration: 59.90 minutes
# Average Inter-Arrival Time: 1.57 minutes
# Total Parked Customers: 11092
# Total Lost Customers: 2768
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 7.22%
# 12-16:59: 13.78%
# 17-20:00: 16.35%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.83%
# Total Revenue: ₹375625.00
# Average Parking Duration: 59.60 minutes
# Average Inter-Arrival Time: 1.66 minutes
# Total Parked Customers: 10612
# Total Lost Customers: 2625
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.93%
# 12-16:59: 13.11%
# 17-20:00: 15.45%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.80%
# Total Revenue: ₹360935.00
# Average Parking Duration: 59.84 minutes
# Average Inter-Arrival Time: 1.69 minutes
# Total Parked Customers: 10148
# Total Lost Customers: 2506
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.57%
# 12-16:59: 12.49%
# 17-20:00: 15.12%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.01%
# Total Revenue: ₹334120.00
# Average Parking Duration: 60.00 minutes
# Average Inter-Arrival Time: 1.84 minutes
# Total Parked Customers: 9409
# Total Lost Customers: 2353
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 6.13%
# 12-16:59: 11.78%
# 17-20:00: 13.75%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.54%
# Total Revenue: ₹322980.00
# Average Parking Duration: 59.15 minutes
# Average Inter-Arrival Time: 1.91 minutes
# Total Parked Customers: 9165
# Total Lost Customers: 2226
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.89%
# 12-16:59: 11.24%
# 17-20:00: 13.35%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.69%
# Total Revenue: ₹309185.00
# Average Parking Duration: 60.36 minutes
# Average Inter-Arrival Time: 2.00 minutes
# Total Parked Customers: 8627
# Total Lost Customers: 2115
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.64%
# 12-16:59: 10.59%
# 17-20:00: 13.14%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.91%
# Total Revenue: ₹294020.00
# Average Parking Duration: 60.96 minutes
# Average Inter-Arrival Time: 2.10 minutes
# Total Parked Customers: 8132
# Total Lost Customers: 2022
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.54%
# 12-16:59: 10.13%
# 17-20:00: 12.25%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.76%
# Total Revenue: ₹280855.00
# Average Parking Duration: 61.35 minutes
# Average Inter-Arrival Time: 2.23 minutes
# Total Parked Customers: 7746
# Total Lost Customers: 1908
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 5.11%
# 12-16:59: 9.88%
# 17-20:00: 11.69%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.87%
# Total Revenue: ₹266370.00
# Average Parking Duration: 60.65 minutes
# Average Inter-Arrival Time: 2.34 minutes
# Total Parked Customers: 7402
# Total Lost Customers: 1835
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.94%
# 12-16:59: 9.19%
# 17-20:00: 11.08%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.57%
# Total Revenue: ₹246330.00
# Average Parking Duration: 59.58 minutes
# Average Inter-Arrival Time: 2.48 minutes
# Total Parked Customers: 6950
# Total Lost Customers: 1800
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.51%
# 12-16:59: 8.42%
# 17-20:00: 10.51%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.64%
# Total Revenue: ₹235390.00
# Average Parking Duration: 61.41 minutes
# Average Inter-Arrival Time: 2.66 minutes
# Total Parked Customers: 6500
# Total Lost Customers: 1691
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.46%
# 12-16:59: 8.03%
# 17-20:00: 10.11%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.21%
# Total Revenue: ₹226775.00
# Average Parking Duration: 59.85 minutes
# Average Inter-Arrival Time: 2.71 minutes
# Total Parked Customers: 6374
# Total Lost Customers: 1614
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.44%
# 12-16:59: 7.84%
# 17-20:00: 9.10%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.44%
# Total Revenue: ₹215680.00
# Average Parking Duration: 60.53 minutes
# Average Inter-Arrival Time: 2.89 minutes
# Total Parked Customers: 5998
# Total Lost Customers: 1447
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 4.12%
# 12-16:59: 7.11%
# 17-20:00: 9.37%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.95%
# Total Revenue: ₹199665.00
# Average Parking Duration: 59.16 minutes
# Average Inter-Arrival Time: 3.05 minutes
# Total Parked Customers: 5661
# Total Lost Customers: 1411
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.56%
# 12-16:59: 6.77%
# 17-20:00: 8.61%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.01%
# Total Revenue: ₹194690.00
# Average Parking Duration: 60.05 minutes
# Average Inter-Arrival Time: 3.14 minutes
# Total Parked Customers: 5470
# Total Lost Customers: 1368
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.75%
# 12-16:59: 6.57%
# 17-20:00: 8.21%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.68%
# Total Revenue: ₹174810.00
# Average Parking Duration: 57.32 minutes
# Average Inter-Arrival Time: 3.37 minutes
# Total Parked Customers: 5060
# Total Lost Customers: 1319
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.28%
# 12-16:59: 5.94%
# 17-20:00: 7.13%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.92%
# Total Revenue: ₹171025.00
# Average Parking Duration: 60.19 minutes
# Average Inter-Arrival Time: 3.57 minutes
# Total Parked Customers: 4792
# Total Lost Customers: 1268
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.11%
# 12-16:59: 5.95%
# 17-20:00: 7.17%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.73%
# Total Revenue: ₹160335.00
# Average Parking Duration: 58.00 minutes
# Average Inter-Arrival Time: 3.77 minutes
# Total Parked Customers: 4592
# Total Lost Customers: 1201
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.05%
# 12-16:59: 5.36%
# 17-20:00: 6.66%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.52%
# Total Revenue: ₹157325.00
# Average Parking Duration: 59.81 minutes
# Average Inter-Arrival Time: 3.89 minutes
# Total Parked Customers: 4439
# Total Lost Customers: 1146
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 3.11%
# 12-16:59: 5.25%
# 17-20:00: 6.75%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.94%
# Total Revenue: ₹151685.00
# Average Parking Duration: 60.27 minutes
# Average Inter-Arrival Time: 4.06 minutes
# Total Parked Customers: 4231
# Total Lost Customers: 1054
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.98%
# 12-16:59: 5.26%
# 17-20:00: 6.15%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.59%
# Total Revenue: ₹141345.00
# Average Parking Duration: 60.20 minutes
# Average Inter-Arrival Time: 4.40 minutes
# Total Parked Customers: 3957
# Total Lost Customers: 964
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.46%
# 12-16:59: 5.15%
# 17-20:00: 5.77%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.08%
# Total Revenue: ₹130600.00
# Average Parking Duration: 58.26 minutes
# Average Inter-Arrival Time: 4.71 minutes
# Total Parked Customers: 3746
# Total Lost Customers: 883
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.51%
# 12-16:59: 4.30%
# 17-20:00: 5.65%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.85%
# Total Revenue: ₹127095.00
# Average Parking Duration: 58.69 minutes
# Average Inter-Arrival Time: 4.84 minutes
# Total Parked Customers: 3610
# Total Lost Customers: 894
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.38%
# 12-16:59: 4.43%
# 17-20:00: 5.18%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.58%
# Total Revenue: ₹118320.00
# Average Parking Duration: 59.30 minutes
# Average Inter-Arrival Time: 5.12 minutes
# Total Parked Customers: 3361
# Total Lost Customers: 871
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.14%
# 12-16:59: 4.20%
# 17-20:00: 4.91%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.43%
# Total Revenue: ₹113665.00
# Average Parking Duration: 60.00 minutes
# Average Inter-Arrival Time: 5.39 minutes
# Total Parked Customers: 3205
# Total Lost Customers: 773
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.11%
# 12-16:59: 4.05%
# 17-20:00: 4.71%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.79%
# Total Revenue: ₹108580.00
# Average Parking Duration: 59.88 minutes
# Average Inter-Arrival Time: 5.69 minutes
# Total Parked Customers: 3059
# Total Lost Customers: 803
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.15%
# 12-16:59: 3.64%
# 17-20:00: 4.65%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.83%
# Total Revenue: ₹105705.00
# Average Parking Duration: 61.79 minutes
# Average Inter-Arrival Time: 5.96 minutes
# Total Parked Customers: 2910
# Total Lost Customers: 720
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 2.01%
# 12-16:59: 3.73%
# 17-20:00: 4.54%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.23%
# Total Revenue: ₹99590.00
# Average Parking Duration: 59.96 minutes
# Average Inter-Arrival Time: 6.09 minutes
# Total Parked Customers: 2796
# Total Lost Customers: 709
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.98%
# 12-16:59: 3.39%
# 17-20:00: 4.14%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.06%
# Total Revenue: ₹94700.00
# Average Parking Duration: 61.46 minutes
# Average Inter-Arrival Time: 6.62 minutes
# Total Parked Customers: 2614
# Total Lost Customers: 656
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.88%
# 12-16:59: 3.29%
# 17-20:00: 3.94%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.67%
# Total Revenue: ₹88495.00
# Average Parking Duration: 59.40 minutes
# Average Inter-Arrival Time: 6.99 minutes
# Total Parked Customers: 2504
# Total Lost Customers: 613
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.66%
# 12-16:59: 3.13%
# 17-20:00: 3.66%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.90%
# Total Revenue: ₹83600.00
# Average Parking Duration: 59.91 minutes
# Average Inter-Arrival Time: 7.42 minutes
# Total Parked Customers: 2354
# Total Lost Customers: 585
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.38%
# 12-16:59: 3.02%
# 17-20:00: 3.61%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.20%
# Total Revenue: ₹83560.00
# Average Parking Duration: 59.16 minutes
# Average Inter-Arrival Time: 7.43 minutes
# Total Parked Customers: 2365
# Total Lost Customers: 562
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.65%
# 12-16:59: 2.85%
# 17-20:00: 3.52%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.39%
# Total Revenue: ₹76950.00
# Average Parking Duration: 61.12 minutes
# Average Inter-Arrival Time: 8.10 minutes
# Total Parked Customers: 2131
# Total Lost Customers: 580
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.42%
# 12-16:59: 2.77%
# 17-20:00: 3.26%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.62%
# Total Revenue: ₹71470.00
# Average Parking Duration: 60.98 minutes
# Average Inter-Arrival Time: 8.76 minutes
# Total Parked Customers: 1979
# Total Lost Customers: 514
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.39%
# 12-16:59: 2.50%
# 17-20:00: 3.03%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.79%
# Total Revenue: ₹68485.00
# Average Parking Duration: 58.69 minutes
# Average Inter-Arrival Time: 8.90 minutes
# Total Parked Customers: 1945
# Total Lost Customers: 480
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.31%
# 12-16:59: 2.35%
# 17-20:00: 2.84%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.36%
# Total Revenue: ₹60915.00
# Average Parking Duration: 57.70 minutes
# Average Inter-Arrival Time: 9.88 minutes
# Total Parked Customers: 1766
# Total Lost Customers: 424
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.18%
# 12-16:59: 2.08%
# 17-20:00: 2.70%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.62%
# Total Revenue: ₹60800.00
# Average Parking Duration: 58.93 minutes
# Average Inter-Arrival Time: 10.30 minutes
# Total Parked Customers: 1725
# Total Lost Customers: 421
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.27%
# 12-16:59: 2.05%
# 17-20:00: 2.63%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 22.39%
# Total Revenue: ₹58160.00
# Average Parking Duration: 60.35 minutes
# Average Inter-Arrival Time: 10.43 minutes
# Total Parked Customers: 1629
# Total Lost Customers: 470
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.15%
# 12-16:59: 2.14%
# 17-20:00: 2.44%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.18%
# Total Revenue: ₹51405.00
# Average Parking Duration: 57.65 minutes
# Average Inter-Arrival Time: 11.67 minutes
# Total Parked Customers: 1487
# Total Lost Customers: 376
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.02%
# 12-16:59: 1.73%
# 17-20:00: 2.26%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.66%
# Total Revenue: ₹51050.00
# Average Parking Duration: 59.62 minutes
# Average Inter-Arrival Time: 11.86 minutes
# Total Parked Customers: 1438
# Total Lost Customers: 352
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.02%
# 12-16:59: 1.78%
# 17-20:00: 2.22%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.24%
# Total Revenue: ₹50110.00
# Average Parking Duration: 59.06 minutes
# Average Inter-Arrival Time: 12.20 minutes
# Total Parked Customers: 1423
# Total Lost Customers: 361
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 1.08%
# 12-16:59: 1.72%
# 17-20:00: 2.18%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.42%
# Total Revenue: ₹45675.00
# Average Parking Duration: 58.06 minutes
# Average Inter-Arrival Time: 13.55 minutes
# Total Parked Customers: 1302
# Total Lost Customers: 334
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.98%
# 12-16:59: 1.60%
# 17-20:00: 1.91%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.82%
# Total Revenue: ₹46055.00
# Average Parking Duration: 60.84 minutes
# Average Inter-Arrival Time: 13.91 minutes
# Total Parked Customers: 1282
# Total Lost Customers: 317
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.91%
# 12-16:59: 1.63%
# 17-20:00: 2.11%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.23%
# Total Revenue: ₹42330.00
# Average Parking Duration: 60.09 minutes
# Average Inter-Arrival Time: 14.43 minutes
# Total Parked Customers: 1195
# Total Lost Customers: 303
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.78%
# 12-16:59: 1.54%
# 17-20:00: 2.04%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.38%
# Total Revenue: ₹43195.00
# Average Parking Duration: 62.32 minutes
# Average Inter-Arrival Time: 15.16 minutes
# Total Parked Customers: 1177
# Total Lost Customers: 283
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.90%
# 12-16:59: 1.58%
# 17-20:00: 1.88%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.94%
# Total Revenue: ₹37480.00
# Average Parking Duration: 58.10 minutes
# Average Inter-Arrival Time: 15.99 minutes
# Total Parked Customers: 1072
# Total Lost Customers: 267
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.83%
# 12-16:59: 1.35%
# 17-20:00: 1.63%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.16%
# Total Revenue: ₹37260.00
# Average Parking Duration: 58.77 minutes
# Average Inter-Arrival Time: 16.94 minutes
# Total Parked Customers: 1065
# Total Lost Customers: 269
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.73%
# 12-16:59: 1.47%
# 17-20:00: 1.61%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.28%
# Total Revenue: ₹36655.00
# Average Parking Duration: 60.99 minutes
# Average Inter-Arrival Time: 17.05 minutes
# Total Parked Customers: 1018
# Total Lost Customers: 259
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.83%
# 12-16:59: 1.27%
# 17-20:00: 1.74%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.96%
# Total Revenue: ₹31865.00
# Average Parking Duration: 59.19 minutes
# Average Inter-Arrival Time: 18.47 minutes
# Total Parked Customers: 905
# Total Lost Customers: 240
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.69%
# 12-16:59: 1.22%
# 17-20:00: 1.45%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.25%
# Total Revenue: ₹32980.00
# Average Parking Duration: 57.18 minutes
# Average Inter-Arrival Time: 17.99 minutes
# Total Parked Customers: 954
# Total Lost Customers: 213
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.70%
# 12-16:59: 1.22%
# 17-20:00: 1.53%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.14%
# Total Revenue: ₹28345.00
# Average Parking Duration: 60.96 minutes
# Average Inter-Arrival Time: 22.35 minutes
# Total Parked Customers: 785
# Total Lost Customers: 198
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.73%
# 12-16:59: 1.06%
# 17-20:00: 1.34%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.57%
# Total Revenue: ₹29010.00
# Average Parking Duration: 61.01 minutes
# Average Inter-Arrival Time: 22.79 minutes
# Total Parked Customers: 798
# Total Lost Customers: 182
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.67%
# 12-16:59: 1.09%
# 17-20:00: 1.31%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.66%
# Total Revenue: ₹27000.00
# Average Parking Duration: 59.05 minutes
# Average Inter-Arrival Time: 23.04 minutes
# Total Parked Customers: 767
# Total Lost Customers: 176
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.65%
# 12-16:59: 1.07%
# 17-20:00: 1.27%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.05%
# Total Revenue: ₹23380.00
# Average Parking Duration: 59.68 minutes
# Average Inter-Arrival Time: 28.83 minutes
# Total Parked Customers: 654
# Total Lost Customers: 164
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.57%
# 12-16:59: 0.89%
# 17-20:00: 1.21%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.18%
# Total Revenue: ₹27425.00
# Average Parking Duration: 63.21 minutes
# Average Inter-Arrival Time: 24.76 minutes
# Total Parked Customers: 733
# Total Lost Customers: 174
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.76%
# 12-16:59: 1.03%
# 17-20:00: 1.14%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.02%
# Total Revenue: ₹22430.00
# Average Parking Duration: 65.89 minutes
# Average Inter-Arrival Time: 29.77 minutes
# Total Parked Customers: 592
# Total Lost Customers: 177
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.59%
# 12-16:59: 0.87%
# 17-20:00: 1.14%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.75%
# Total Revenue: ₹22450.00
# Average Parking Duration: 58.54 minutes
# Average Inter-Arrival Time: 29.64 minutes
# Total Parked Customers: 634
# Total Lost Customers: 156
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.52%
# 12-16:59: 0.93%
# 17-20:00: 1.00%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 22.66%
# Total Revenue: ₹19625.00
# Average Parking Duration: 58.39 minutes
# Average Inter-Arrival Time: 29.07 minutes
# Total Parked Customers: 563
# Total Lost Customers: 165
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.82%
# 17-20:00: 0.94%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.00%
# Total Revenue: ₹18485.00
# Average Parking Duration: 59.14 minutes
# Average Inter-Arrival Time: 33.76 minutes
# Total Parked Customers: 528
# Total Lost Customers: 132
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.56%
# 12-16:59: 0.84%
# 17-20:00: 0.86%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.18%
# Total Revenue: ₹16760.00
# Average Parking Duration: 59.88 minutes
# Average Inter-Arrival Time: 37.23 minutes
# Total Parked Customers: 472
# Total Lost Customers: 112
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.52%
# 12-16:59: 0.65%
# 17-20:00: 1.07%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 17.16%
# Total Revenue: ₹18120.00
# Average Parking Duration: 56.39 minutes
# Average Inter-Arrival Time: 33.54 minutes
# Total Parked Customers: 536
# Total Lost Customers: 111
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.47%
# 12-16:59: 0.83%
# 17-20:00: 0.92%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.71%
# Total Revenue: ₹15005.00
# Average Parking Duration: 54.39 minutes
# Average Inter-Arrival Time: 39.18 minutes
# Total Parked Customers: 452
# Total Lost Customers: 104
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.45%
# 12-16:59: 0.71%
# 17-20:00: 0.84%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.64%
# Total Revenue: ₹12715.00
# Average Parking Duration: 57.09 minutes
# Average Inter-Arrival Time: 50.06 minutes
# Total Parked Customers: 373
# Total Lost Customers: 103
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.49%
# 12-16:59: 0.61%
# 17-20:00: 0.74%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 22.14%
# Total Revenue: ₹14710.00
# Average Parking Duration: 62.43 minutes
# Average Inter-Arrival Time: 41.61 minutes
# Total Parked Customers: 401
# Total Lost Customers: 114
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.51%
# 12-16:59: 0.64%
# 17-20:00: 0.86%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.12%
# Total Revenue: ₹14235.00
# Average Parking Duration: 57.64 minutes
# Average Inter-Arrival Time: 43.26 minutes
# Total Parked Customers: 413
# Total Lost Customers: 104
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.40%
# 12-16:59: 0.72%
# 17-20:00: 0.84%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.46%
# Total Revenue: ₹14505.00
# Average Parking Duration: 62.60 minutes
# Average Inter-Arrival Time: 48.13 minutes
# Total Parked Customers: 393
# Total Lost Customers: 89
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.43%
# 12-16:59: 0.73%
# 17-20:00: 0.77%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 22.51%
# Total Revenue: ₹12780.00
# Average Parking Duration: 59.86 minutes
# Average Inter-Arrival Time: 48.39 minutes
# Total Parked Customers: 365
# Total Lost Customers: 106
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.49%
# 12-16:59: 0.62%
# 17-20:00: 0.77%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.44%
# Total Revenue: ₹13685.00
# Average Parking Duration: 56.40 minutes
# Average Inter-Arrival Time: 46.62 minutes
# Total Parked Customers: 398
# Total Lost Customers: 90
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.46%
# 12-16:59: 0.70%
# 17-20:00: 0.69%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.35%
# Total Revenue: ₹10595.00
# Average Parking Duration: 58.18 minutes
# Average Inter-Arrival Time: 58.42 minutes
# Total Parked Customers: 302
# Total Lost Customers: 82
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.37%
# 12-16:59: 0.56%
# 17-20:00: 0.77%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 15.29%
# Total Revenue: ₹11975.00
# Average Parking Duration: 57.49 minutes
# Average Inter-Arrival Time: 56.96 minutes
# Total Parked Customers: 338
# Total Lost Customers: 61
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.42%
# 12-16:59: 0.63%
# 17-20:00: 0.67%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.64%
# Total Revenue: ₹8805.00
# Average Parking Duration: 53.18 minutes
# Average Inter-Arrival Time: 69.81 minutes
# Total Parked Customers: 266
# Total Lost Customers: 65
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.37%
# 12-16:59: 0.52%
# 17-20:00: 0.66%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.42%
# Total Revenue: ₹9535.00
# Average Parking Duration: 58.31 minutes
# Average Inter-Arrival Time: 66.20 minutes
# Total Parked Customers: 278
# Total Lost Customers: 67
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.45%
# 12-16:59: 0.53%
# 17-20:00: 0.63%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.92%
# Total Revenue: ₹10045.00
# Average Parking Duration: 67.70 minutes
# Average Inter-Arrival Time: 68.87 minutes
# Total Parked Customers: 257
# Total Lost Customers: 68
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.46%
# 12-16:59: 0.50%
# 17-20:00: 0.69%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 15.71%
# Total Revenue: ₹8110.00
# Average Parking Duration: 62.55 minutes
# Average Inter-Arrival Time: 91.51 minutes
# Total Parked Customers: 220
# Total Lost Customers: 41
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.34%
# 12-16:59: 0.53%
# 17-20:00: 0.74%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.94%
# Total Revenue: ₹7775.00
# Average Parking Duration: 61.71 minutes
# Average Inter-Arrival Time: 90.77 minutes
# Total Parked Customers: 214
# Total Lost Customers: 50
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.50%
# 17-20:00: 0.44%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.30%
# Total Revenue: ₹8470.00
# Average Parking Duration: 69.62 minutes
# Average Inter-Arrival Time: 90.50 minutes
# Total Parked Customers: 212
# Total Lost Customers: 54
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.40%
# 12-16:59: 0.46%
# 17-20:00: 0.79%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.40%
# Total Revenue: ₹7820.00
# Average Parking Duration: 65.22 minutes
# Average Inter-Arrival Time: 85.90 minutes
# Total Parked Customers: 204
# Total Lost Customers: 46
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.51%
# 12-16:59: 0.43%
# 17-20:00: 0.62%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.46%
# Total Revenue: ₹6370.00
# Average Parking Duration: 55.98 minutes
# Average Inter-Arrival Time: 91.85 minutes
# Total Parked Customers: 186
# Total Lost Customers: 57
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.41%
# 12-16:59: 0.47%
# 17-20:00: 0.52%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.60%
# Total Revenue: ₹6935.00
# Average Parking Duration: 57.72 minutes
# Average Inter-Arrival Time: 95.48 minutes
# Total Parked Customers: 201
# Total Lost Customers: 49
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.47%
# 12-16:59: 0.44%
# 17-20:00: 0.55%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 24.63%
# Total Revenue: ₹5575.00
# Average Parking Duration: 63.25 minutes
# Average Inter-Arrival Time: 113.79 minutes
# Total Parked Customers: 153
# Total Lost Customers: 50
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.56%
# 12-16:59: 0.39%
# 17-20:00: 0.48%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.38%
# Total Revenue: ₹4030.00
# Average Parking Duration: 53.66 minutes
# Average Inter-Arrival Time: 145.17 minutes
# Total Parked Customers: 125
# Total Lost Customers: 34
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.52%
# 12-16:59: 0.22%
# 17-20:00: 0.60%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 15.95%
# Total Revenue: ₹4955.00
# Average Parking Duration: 60.76 minutes
# Average Inter-Arrival Time: 147.19 minutes
# Total Parked Customers: 137
# Total Lost Customers: 26
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.51%
# 12-16:59: 0.37%
# 17-20:00: 0.46%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.10%
# Total Revenue: ₹5320.00
# Average Parking Duration: 63.39 minutes
# Average Inter-Arrival Time: 134.92 minutes
# Total Parked Customers: 144
# Total Lost Customers: 34
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.56%
# 12-16:59: 0.37%
# 17-20:00: 0.43%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.00%
# Total Revenue: ₹5260.00
# Average Parking Duration: 57.63 minutes
# Average Inter-Arrival Time: 129.70 minutes
# Total Parked Customers: 152
# Total Lost Customers: 38
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.34%
# 12-16:59: 0.50%
# 17-20:00: 0.44%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 13.91%
# Total Revenue: ₹4780.00
# Average Parking Duration: 60.34 minutes
# Average Inter-Arrival Time: 174.06 minutes
# Total Parked Customers: 130
# Total Lost Customers: 21
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.39%
# 12-16:59: 0.36%
# 17-20:00: 0.61%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.07%
# Total Revenue: ₹5210.00
# Average Parking Duration: 65.93 minutes
# Average Inter-Arrival Time: 144.55 minutes
# Total Parked Customers: 136
# Total Lost Customers: 30
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.52%
# 12-16:59: 0.41%
# 17-20:00: 0.44%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 21.53%
# Total Revenue: ₹3930.00
# Average Parking Duration: 59.91 minutes
# Average Inter-Arrival Time: 154.68 minutes
# Total Parked Customers: 113
# Total Lost Customers: 31
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.41%
# 12-16:59: 0.48%
# 17-20:00: 0.34%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 29.85%
# Total Revenue: ₹3370.00
# Average Parking Duration: 58.67 minutes
# Average Inter-Arrival Time: 183.63 minutes
# Total Parked Customers: 94
# Total Lost Customers: 40
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.52%
# 12-16:59: 0.42%
# 17-20:00: 0.32%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.00%
# Total Revenue: ₹2775.00
# Average Parking Duration: 60.33 minutes
# Average Inter-Arrival Time: 322.68 minutes
# Total Parked Customers: 77
# Total Lost Customers: 23
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.45%
# 12-16:59: 0.37%
# 17-20:00: 0.45%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 27.27%
# Total Revenue: ₹3230.00
# Average Parking Duration: 59.97 minutes
# Average Inter-Arrival Time: 237.07 minutes
# Total Parked Customers: 88
# Total Lost Customers: 33
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.53%
# 12-16:59: 0.27%
# 17-20:00: 0.46%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 15.32%
# Total Revenue: ₹2670.00
# Average Parking Duration: 42.83 minutes
# Average Inter-Arrival Time: 259.05 minutes
# Total Parked Customers: 94
# Total Lost Customers: 17
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.33%
# 17-20:00: 0.36%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 26.85%
# Total Revenue: ₹2480.00
# Average Parking Duration: 51.17 minutes
# Average Inter-Arrival Time: 222.93 minutes
# Total Parked Customers: 79
# Total Lost Customers: 29
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.50%
# 12-16:59: 0.31%
# 17-20:00: 0.46%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.82%
# Total Revenue: ₹3485.00
# Average Parking Duration: 67.01 minutes
# Average Inter-Arrival Time: 242.64 minutes
# Total Parked Customers: 89
# Total Lost Customers: 22
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.34%
# 17-20:00: 0.40%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 15.96%
# Total Revenue: ₹2660.00
# Average Parking Duration: 54.87 minutes
# Average Inter-Arrival Time: 323.97 minutes
# Total Parked Customers: 79
# Total Lost Customers: 15
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.40%
# 12-16:59: 0.33%
# 17-20:00: 0.53%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 22.47%
# Total Revenue: ₹2260.00
# Average Parking Duration: 52.20 minutes
# Average Inter-Arrival Time: 354.26 minutes
# Total Parked Customers: 69
# Total Lost Customers: 20
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.60%
# 12-16:59: 0.23%
# 17-20:00: 0.45%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.00%
# Total Revenue: ₹2310.00
# Average Parking Duration: 56.85 minutes
# Average Inter-Arrival Time: 389.79 minutes
# Total Parked Customers: 68
# Total Lost Customers: 17
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.53%
# 12-16:59: 0.32%
# 17-20:00: 0.35%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 25.32%
# Total Revenue: ₹2070.00
# Average Parking Duration: 59.09 minutes
# Average Inter-Arrival Time: 444.18 minutes
# Total Parked Customers: 59
# Total Lost Customers: 20
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.36%
# 17-20:00: 0.30%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 11.11%
# Total Revenue: ₹2140.00
# Average Parking Duration: 53.06 minutes
# Average Inter-Arrival Time: 471.09 minutes
# Total Parked Customers: 64
# Total Lost Customers: 8
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.54%
# 12-16:59: 0.25%
# 17-20:00: 0.39%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 14.49%
# Total Revenue: ₹2040.00
# Average Parking Duration: 57.07 minutes
# Average Inter-Arrival Time: 506.66 minutes
# Total Parked Customers: 59
# Total Lost Customers: 10
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.44%
# 12-16:59: 0.50%
# 17-20:00: 0.22%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 16.44%
# Total Revenue: ₹2290.00
# Average Parking Duration: 63.75 minutes
# Average Inter-Arrival Time: 509.22 minutes
# Total Parked Customers: 61
# Total Lost Customers: 12
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.64%
# 12-16:59: 0.23%
# 17-20:00: 0.43%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.06%
# Total Revenue: ₹2145.00
# Average Parking Duration: 62.62 minutes
# Average Inter-Arrival Time: 443.03 minutes
# Total Parked Customers: 59
# Total Lost Customers: 13
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.47%
# 12-16:59: 0.40%
# 17-20:00: 0.33%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 13.64%
# Total Revenue: ₹1705.00
# Average Parking Duration: 46.57 minutes
# Average Inter-Arrival Time: 599.69 minutes
# Total Parked Customers: 57
# Total Lost Customers: 9
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.49%
# 12-16:59: 0.29%
# 17-20:00: 0.42%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.59%
# Total Revenue: ₹1785.00
# Average Parking Duration: 55.89 minutes
# Average Inter-Arrival Time: 600.90 minutes
# Total Parked Customers: 54
# Total Lost Customers: 14
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.29%
# 12-16:59: 0.51%
# 17-20:00: 0.39%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 19.67%
# Total Revenue: ₹1530.00
# Average Parking Duration: 50.30 minutes
# Average Inter-Arrival Time: 572.67 minutes
# Total Parked Customers: 49
# Total Lost Customers: 12
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.55%
# 12-16:59: 0.24%
# 17-20:00: 0.41%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 23.21%
# Total Revenue: ₹1660.00
# Average Parking Duration: 68.94 minutes
# Average Inter-Arrival Time: 738.15 minutes
# Total Parked Customers: 43
# Total Lost Customers: 13
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.42%
# 12-16:59: 0.41%
# 17-20:00: 0.37%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 26.79%
# Total Revenue: ₹2135.00
# Average Parking Duration: 101.06 minutes
# Average Inter-Arrival Time: 700.09 minutes
# Total Parked Customers: 41
# Total Lost Customers: 15
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.45%
# 12-16:59: 0.26%
# 17-20:00: 0.62%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 17.31%
# Total Revenue: ₹1560.00
# Average Parking Duration: 61.06 minutes
# Average Inter-Arrival Time: 850.23 minutes
# Total Parked Customers: 43
# Total Lost Customers: 9
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.60%
# 12-16:59: 0.38%
# 17-20:00: 0.18%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 18.18%
# Total Revenue: ₹1465.00
# Average Parking Duration: 52.86 minutes
# Average Inter-Arrival Time: 595.58 minutes
# Total Parked Customers: 45
# Total Lost Customers: 10
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.44%
# 12-16:59: 0.36%
# 17-20:00: 0.32%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 20.37%
# Total Revenue: ₹1685.00
# Average Parking Duration: 69.43 minutes
# Average Inter-Arrival Time: 842.12 minutes
# Total Parked Customers: 43
# Total Lost Customers: 11
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.49%
# 12-16:59: 0.36%
# 17-20:00: 0.36%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 27.66%
# Total Revenue: ₹990.00
# Average Parking Duration: 46.75 minutes
# Average Inter-Arrival Time: 929.82 minutes
# Total Parked Customers: 34
# Total Lost Customers: 13
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.69%
# 12-16:59: 0.33%
# 17-20:00: 0.12%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 13.46%
# Total Revenue: ₹1415.00
# Average Parking Duration: 53.36 minutes
# Average Inter-Arrival Time: 726.29 minutes
# Total Parked Customers: 45
# Total Lost Customers: 7
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.39%
# 12-16:59: 0.30%
# 17-20:00: 0.54%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 25.93%
# Total Revenue: ₹1215.00
# Average Parking Duration: 47.90 minutes
# Average Inter-Arrival Time: 679.42 minutes
# Total Parked Customers: 40
# Total Lost Customers: 14
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.31%
# 12-16:59: 0.38%
# 17-20:00: 0.52%
# Adjusting arrival rates...
#
# Simulation Results after Adjusting Arrival Rates:
# Current Lost Customer Percentage: 9.80%
# Total Revenue: ₹1720.00
# Average Parking Duration: 66.04 minutes
# Average Inter-Arrival Time: 819.62 minutes
# Total Parked Customers: 46
# Total Lost Customers: 5
#
# Average Parking Space Utilization by Time Slot:
# 8-11:59: 0.19%
# 12-16:59: 0.58%
# 17-20:00: 0.40%
# Lost customer percentage is within the acceptable range: 9.80%
